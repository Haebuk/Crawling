# %%
import pandas as pd
df = pd.read_csv('brand_list.csv')
df
# Out:
#      브랜드명 키워드1    키워드2   키워드3 키워드4
# 0      게스   게스   guess    NaN  NaN
# 1      겐조   겐조   kenzo    NaN  NaN
# 2      구찌   구찌   gucci    NaN  NaN
# 3   꼼데가르송   꼼데   comme    NaN  NaN
# 4     끌로에  끌로에   chloe    NaN  NaN
# ..    ...  ...     ...    ...  ...
# 58      갭    갭     gap    NaN  NaN
# 59    엄브로  엄브로   umbro    NaN  NaN
# 60    해지스  해지스  hazzys    NaN  NaN
# 61     빔스   빔스      빔즈  beams  NaN
# 62     지유   지유      GU     gu  NaN
#
# [63 rows x 5 columns]

# %%
from check_length import *
# Out:
# 브랜드명       게스
# 키워드1       게스
# 키워드2    guess
# 키워드3      NaN
# 키워드4      NaN
# Name: 0, dtype: object
# 브랜드명       겐조
# 키워드1       겐조
# 키워드2    kenzo
# 키워드3      NaN
# 키워드4      NaN
# Name: 1, dtype: object
# 브랜드명       구찌
# 키워드1       구찌
# 키워드2    gucci
# 키워드3      NaN
# 키워드4      NaN
# Name: 2, dtype: object
# 브랜드명    꼼데가르송
# 키워드1       꼼데
# 키워드2    comme
# 키워드3      NaN
# 키워드4      NaN
# Name: 3, dtype: object
# 브랜드명      끌로에
# 키워드1      끌로에
# 키워드2    chloe
# 키워드3      NaN
# 키워드4      NaN
# Name: 4, dtype: object
# 브랜드명     나이키
# 키워드1     나이키
# 키워드2    nike
# 키워드3     NaN
# 키워드4     NaN
# Name: 5, dtype: object
# 브랜드명        노스페이스
# 키워드1        노스페이스
# 키워드2    northface
# 키워드3          NaN
# 키워드4          NaN
# Name: 6, dtype: object
# 브랜드명          뉴발란스
# 키워드1          뉴발란스
# 키워드2    newbalance
# 키워드3           NaN
# 키워드4           NaN
# Name: 7, dtype: object
# 브랜드명         던힐
# 키워드1         던힐
# 키워드2    dunhill
# 키워드3        NaN
# 키워드4        NaN
# Name: 8, dtype: object
# ...

# %%
df.head(3)
# Out:
#   브랜드명 키워드1   키워드2 키워드3 키워드4
# 0   게스   게스  guess  NaN  NaN
# 1   겐조   겐조  kenzo  NaN  NaN
# 2   구찌   구찌  gucci  NaN  NaN

# %%
keyword = '게스'
value = df.loc[
    (df['키워드1'] == keyword) |
    (df['키워드2'] == keyword) |
    (df['키워드3'] == keyword) |
    (df['키워드4'] == keyword) |
    (df['브랜드명'] == keyword),
    '브랜드명'
].values[0]
# Out:
# '게스'
